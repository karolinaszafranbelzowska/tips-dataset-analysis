# %% [markdown]
# ### Import pandas, numpy, seaborn and matplotlib.pyplot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load the **tips** dataset from URL
# ### Taken from : **https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv**

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %% [markdown]
#  **pd.read_csv** function reads a csv file from the URL

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### There are 244 rows and 7 columns
# Each row describes each customer in a restaurant whereas each column describes 7 different features. **First** column shows "Total_bill", **Second** column: "Tip", **Third** column: "Sex", **Fourth** column: "Smoker", **Fifth** column: "Day", **Sixth** column: "Time" and **Seventh** column: "Size".

# %% [markdown]
# ### Some statistics of the tips-dataset

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# ### Scatter plot

# %%
df[['total_bill', 'sex']].head()
# Out:
#    total_bill     sex
# 0       16.99  Female
# 1       10.34    Male
# 2       21.01    Male
# 3       23.68    Male
# 4       24.59  Female

# %%
sns.scatterplot(x='total_bill',y='sex',data=df)

# %%
df[['total_bill', 'tip']].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
sns.set_style("white")
tips = sns.load_dataset("tips")              
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
sns.set_style("whitegrid")
sns.boxplot(data=df, palette="deep")
sns.despine(left=True)

# %% [markdown]
# The next plot will compare three parameters: **total_bill**, **tip** and **sex**. Hue in this case can be eighter numeric or categorical. Here is categorical: Male and Female. I selected three columns with these parameters and I used head() method.

# %%
df[['total_bill', 'tip', 'sex']].head()
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=df)

# %%
df[['total_bill', 'tip','sex', 'smoker']].head()
# Out:
#    total_bill   tip     sex smoker
# 0       16.99  1.01  Female     No
# 1       10.34  1.66    Male     No
# 2       21.01  3.50    Male     No
# 3       23.68  3.31    Male     No
# 4       24.59  3.61  Female     No

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',size='smoker',data=df)

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',size='smoker',data=df)

# %%
df[['total_bill', 'tip','sex', 'smoker', 'day']].head()
# Out:
#    total_bill   tip     sex smoker  day
# 0       16.99  1.01  Female     No  Sun
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun
# 4       24.59  3.61  Female     No  Sun

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',size='smoker',col='day',data=df)

# %%
df[['total_bill', 'tip','sex', 'smoker', 'day', 'time']].head()
# Out:
#    total_bill   tip     sex smoker  day    time
# 0       16.99  1.01  Female     No  Sun  Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',size='smoker',col='day',row='time',height=3,data=df)

# %% [markdown]
# ### Line plot

# %%
sex_vs_tip = sns.relplot(x="sex", y="tip", kind="line", data=df)

# %%
total_bill_vs_tip = sns.relplot(x="total_bill", y="tip", kind="line", data=df)

# %% [markdown]
# ### Ploting with categorical data

# %%
sns.catplot(x="tip",y="sex",data=df)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=df);

# %%
sns.catplot(x="time",y="tip",kind='box',data=df)

# %%
sns.catplot(x="total_bill",y="sex",kind='bar',data=df)

# %%
sns.catplot(x="total_bill",y="sex",kind='bar',hue='smoker',data=df)

# %% [markdown]
# I want to analize just smokers and to select them I used _.loc_ index.

# %%
s = df.loc[df.loc[:,'smoker'] == 'Yes']

# %%
s
# Out:
#         total_bill   tip smoker   day    time  size
# sex
# Male         38.01  3.00    Yes   Sat  Dinner     4
# Male         11.24  1.76    Yes   Sat  Dinner     2
# Male         20.29  3.21    Yes   Sat  Dinner     2
# Male         13.81  2.00    Yes   Sat  Dinner     2
# Male         11.02  1.98    Yes   Sat  Dinner     2
# Male         18.29  3.76    Yes   Sat  Dinner     4
# Female        3.07  1.00    Yes   Sat  Dinner     1
# Male         15.01  2.09    Yes   Sat  Dinner     2
# Female       26.86  3.14    Yes   Sat  Dinner     2
# Female       25.28  5.00    Yes   Sat  Dinner     2
# Male         17.92  3.08    Yes   Sat  Dinner     2
# Male         19.44  3.00    Yes  Thur   Lunch     2
# Male         32.68  5.00    Yes  Thur   Lunch     2
# Male         28.97  3.00    Yes   Fri  Dinner     2
# Female        5.75  1.00    Yes   Fri  Dinner     2
# Female       16.32  4.30    Yes   Fri  Dinner     2
# Male         40.17  4.73    Yes   Fri  Dinner     4
# Male         27.28  4.00    Yes   Fri  Dinner     2
# Male         12.03  1.50    Yes   Fri  Dinner     2
# Male         21.01  3.00    Yes   Fri  Dinner     2
# Female       11.35  2.50    Yes   Fri  Dinner     2
# Female       15.38  3.00    Yes   Fri  Dinner     2
# Female       44.30  2.50    Yes   Sat  Dinner     3
# Female       22.42  3.48    Yes   Sat  Dinner     2
# Male         15.36  1.64    Yes   Sat  Dinner     2
# Male         20.49  4.06    Yes   Sat  Dinner     2
# Male         25.21  4.29    Yes   Sat  Dinner     2
# Female       14.31  4.00    Yes   Sat  Dinner     2
# Male         16.00  2.00    Yes  Thur   Lunch     2
# Female       17.51  3.00    Yes   Sun  Dinner     2
# ...            ...   ...    ...   ...     ...   ...
# Female       16.40  2.50    Yes  Thur   Lunch     2
# Male         20.53  4.00    Yes  Thur   Lunch     4
# Female       16.47  3.23    Yes  Thur   Lunch     3
# Male         26.59  3.41    Yes   Sat  Dinner     3
# Male         38.73  3.00    Yes   Sat  Dinner     4
# Male         24.27  2.03    Yes   Sat  Dinner     2
# Female       12.76  2.23    Yes   Sat  Dinner     2
# Male         30.06  2.00    Yes   Sat  Dinner     3
# Male         25.89  5.16    Yes   Sat  Dinner     4
# Female       13.27  2.50    Yes   Sat  Dinner     2
# Female       28.17  6.50    Yes   Sat  Dinner     3
# Female       12.90  1.10    Yes   Sat  Dinner     2
# Male         28.15  3.00    Yes   Sat  Dinner     5
# Male         11.59  1.50    Yes   Sat  Dinner     2
# Male          7.74  1.44    Yes   Sat  Dinner     2
# Female       30.14  3.09    Yes   Sat  Dinner     4
# Male         12.16  2.20    Yes   Fri   Lunch     2
# Female       13.42  3.48    Yes   Fri   Lunch     2
# Male          8.58  1.92    Yes   Fri   Lunch     1
# Male         13.42  1.58    Yes   Fri   Lunch     2
# Female       16.27  2.50    Yes   Fri   Lunch     2
# Female       10.09  2.00    Yes   Fri   Lunch     2
# Female       22.12  2.88    Yes   Sat  Dinner     2
# Male         24.01  2.00    Yes   Sat  Dinner     4
# Male         15.69  3.00    Yes   Sat  Dinner     3
# Male         15.53  3.00    Yes   Sat  Dinner     2
# Male         12.60  1.00    Yes   Sat  Dinner     2
# Male         32.83  1.17    Yes   Sat  Dinner     2
# Female       27.18  2.00    Yes   Sat  Dinner     2
# Male         22.67  2.00    Yes   Sat  Dinner     2
#
# [93 rows x 6 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=s)

# %%
s.describe()
# Out:
#        total_bill        tip       size
# count   93.000000  93.000000  93.000000
# mean    20.756344   3.008710   2.408602
# std      9.832154   1.401468   0.810751
# min      3.070000   1.000000   1.000000
# 25%     13.420000   2.000000   2.000000
# 50%     17.920000   3.000000   2.000000
# 75%     26.860000   3.680000   3.000000
# max     50.810000  10.000000   5.000000

# %%
n = df.loc[df.loc[:,'smoker'] == 'No']

# %%
n
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 150       14.07  2.50    Male     No   Sun  Dinner     2
# 151       13.13  2.00    Male     No   Sun  Dinner     2
# 152       17.26  2.74    Male     No   Sun  Dinner     3
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 154       19.77  2.00    Male     No   Sun  Dinner     4
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 157       25.00  3.75  Female     No   Sun  Dinner     4
# 158       13.39  2.61  Female     No   Sun  Dinner     2
# 159       16.49  2.00    Male     No   Sun  Dinner     4
# 160       21.50  3.50    Male     No   Sun  Dinner     4
# 161       12.66  2.50    Male     No   Sun  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 163       13.81  2.00    Male     No   Sun  Dinner     2
# 165       24.52  3.48    Male     No   Sun  Dinner     3
# 166       20.76  2.24    Male     No   Sun  Dinner     2
# 167       31.71  4.50    Male     No   Sun  Dinner     4
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=n)

# %%
n.describe()
# Out:
#        total_bill         tip        size
# count  151.000000  151.000000  151.000000
# mean    19.188278    2.991854    2.668874
# std      8.255582    1.377190    1.017984
# min      7.250000    1.000000    1.000000
# 25%     13.325000    2.000000    2.000000
# 50%     17.590000    2.740000    2.000000
# 75%     22.755000    3.505000    3.000000
# max     48.330000    9.000000    6.000000

# %% [markdown]
# There are 93 rows of YES-smokers which means 93 people were smoking during their lunch or dinner and 151 rows of NO-smokers.
# Mean **total_bill** for YES-smoking people is nearly 21 dol, whereas the mean for NO-smoking is 19 dol. It's worth to write that mean for all people is nearly 20 dol. (19.78). So, YES-smoking people seem to pay more for their meals which means they tipped more. Smokers took maximum 5 meals (size), wheareas unsmokers took 6.
